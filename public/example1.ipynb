# %% [markdown]
# # example 1

# %%
print(2)
# Out:
# 2

# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.4 MB 28.8 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 32.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 29.8 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.3 MB 9.7 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.3 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 14.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 26.1 MB/s  0:00:00
# ...

# %%
import numpy as np

# %%
np.add(1,10)
# Out:
# np.int64(11)
